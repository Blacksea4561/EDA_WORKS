# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings;
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("ornek_vir.csv")
df
# Out:
#    a   b   c
# 0  1   2   5
# 1  3   8  10
# 2  4  12  15

# %%
 pd.read_csv("ornek.csv", sep = ";")
# Out:
#    a   b   c
# 0  1   2   5
# 1  3   8  10
# 2  4  12  15

# %%
 pd.read_csv("ornek.csv", sep = ";", index_col =1)
# Out:
#     a   c
# b
# 2   1   5
# 8   3  10
# 12  4  15

# %%
 pd.read_csv("ornek.csv", sep = ";", usecols =["a","c"])
# Out:
#    a   c
# 0  1   5
# 1  3  10
# 2  4  15

# %%
pd.read_csv("ornek_vir.csv", header =2)
# Out:
#    3   8  10
# 0  4  12  15

# %%
pd.read_csv("ornek_tab.csv", sep= "\t")
# Out:
#    a   b   c
# 0  1   2   5
# 1  3   8  10
# 2  4  12  15

# %%
pd.read_csv("ornek_tir.csv",header=2)
# Out:
#    100  200  300
# 0   kk  4.0    3
# 1    5  NaN  Ali
# 2  NaN  8.0  NaN

# %%
pd.read_csv("ornek_tir.csv", na_values= "Ali")
# Out:
#      a      b      c
# 0   10   20.0   30.0
# 1  100  200.0  300.0
# 2   kk    4.0    3.0
# 3    5    NaN    NaN
# 4  NaN    8.0    NaN

# %%
df1
# Out:
#      a      b      c
# 0   10   20.0   30.0
# 1  100  200.0  300.0
# 2   kk    4.0    3.0
# 3    5    NaN    NaN
# 4  NaN    8.0    NaN

# %%
df.to_csv("example.csv")

# %%
pd.read_csv("example.csv")
# Out:
#    Unnamed: 0  a   b   c
# 0           0  1   2   5
# 1           1  3   8  10
# 2           2  4  12  15

# %%
df.to_csv("example.csv", index =False) # gonderiyor

# %%
pd.read_csv("example.csv") # çağırıyor
# Out:
#    a   b   c
# 0  1   2   5
# 1  3   8  10
# 2  4  12  15

# %%
df
# Out:
#    a   b   c
# 0  1   2   5
# 1  3   8  10
# 2  4  12  15

# %%
df1 = pd.read_excel("kitap1.xlsx")

# %%
df1
# Out:
#     a   b    c   d
# 0   1   8   15   3
# 1   2   9  227  11
# 2  32  52  125   5
# 3   4  15    3   1

# %%
df2 = pd.read_excel("kitap1.xlsx", sheet_name="Sayfa2")
df2
# Out:
#     aa   bb   cc  dd
# 0  100  200  300   1
# 1  250  300  350   2
# 2    1    2    3   3
# 3   88   77   88  45

# %%
df3 = pd.read_excel("kitap1.xlsx", sheet_name="Sayfa2") # ex
df3
# Out:
#     aa   bb   cc  dd
# 0  100  200  300   1
# 1  250  300  350   2
# 2    1    2    3   3
# 3   88   77   88  45

# %%
# !pip install openpyxl

# %%
df3 = pd.read_excel("kitap1.xlsx", sheet_name=None)
df3
# Out:
# {'Sayfa1':     a   b    c   d
#  0   1   8   15   3
#  1   2   9  227  11
#  2  32  52  125   5
#  3   4  15    3   1,
#  'Sayfa2':     aa   bb   cc  dd
#  0  100  200  300   1
#  1  250  300  350   2
#  2    1    2    3   3
#  3   88   77   88  45}

# %%
type(df3)
# Out:
# dict

# %%
pd.ExcelFile("kitap1.xlsx").sheet_names
# Out:
# ['Sayfa1', 'Sayfa2']

# %%
df2
# Out:
#     aa   bb   cc  dd
# 0  100  200  300   1
# 1  250  300  350   2
# 2    1    2    3   3
# 3   88   77   88  45

# %%
df2.to_excel("Excel_sample.xlsx")

# %%
with pd.ExcelWriter("combined_df.xlsx") as writer: # bütün syafaları  kaydeder
    df1.to_excel(writer,sheet_name="Sayfa_1",index =False)
    df2.to_excel(writer,sheet_name="Sayfa_2",index =True)

# %%
pd.read_excel("combined_df.xlsx", sheet_name = "Sayfa_2")
# Out:
#    Unnamed: 0   aa   bb   cc  dd
# 0           0  100  200  300   1
# 1           1  250  300  350   2
# 2           2    1    2    3   3
# 3           3   88   77   88  45

# %%
pd.read_excel("combined_df.xlsx", sheet_name = "Sayfa_2",index_col=0)
# Out:
#     aa   bb   cc  dd
# 0  100  200  300   1
# 1  250  300  350   2
# 2    1    2    3   3
# 3   88   77   88  45

# %%
# !pip install lxml

# %%
# !pip install html5lib
# !pip install BeautifulSoup4

# %%
url = "https://en.wikipedia.org/wiki/London" #  html den   data çekme
dfs =pd.read_html(url)
dfs
# Out:
# [                                               London  \
#  0                                        Capital city
#  1   Clockwise from top: City of London in the fore...
#  2   .mw-parser-output .locmap .od{position:absolut...
#  3   Coordinates: .mw-parser-output .geo-default,.m...
#  4                                     Sovereign state
#  5                                             Country
#  6                                              Region
#  7                                 Ceremonial counties
#  8                          Local government districts
#  9                                   Settled by Romans
#  10                                         Government
#  11                                             • Type
#  12                                             • Body
#  13                                  • London Assembly
#  14                                    • UK Parliament
#  15                                               Area
# ...

# %%
dfs[0]
# Out:
#                                                London  \
# 0                                        Capital city
# 1   Clockwise from top: City of London in the fore...
# 2   .mw-parser-output .locmap .od{position:absolut...
# 3   Coordinates: .mw-parser-output .geo-default,.m...
# 4                                     Sovereign state
# 5                                             Country
# 6                                              Region
# 7                                 Ceremonial counties
# 8                          Local government districts
# 9                                   Settled by Romans
# 10                                         Government
# 11                                             • Type
# 12                                             • Body
# 13                                  • London Assembly
# 14                                    • UK Parliament
# 15                                               Area
# ...

# %%
url = "https://en.wikipedia.org/wiki/London"
dfs =pd.read_html(url)
dfs
# Out:
# [                                               London  \
#  0                                        Capital city
#  1   Clockwise from top: City of London in the fore...
#  2   .mw-parser-output .locmap .od{position:absolut...
#  3   Coordinates: .mw-parser-output .geo-default,.m...
#  4                                     Sovereign state
#  5                                             Country
#  6                                              Region
#  7                                 Ceremonial counties
#  8                          Local government districts
#  9                                   Settled by Romans
#  10                                         Government
#  11                                             • Type
#  12                                             • Body
#  13                                  • London Assembly
#  14                                    • UK Parliament
#  15                                               Area
# ...

# %%
dfhtml = pd.read_html('https://www.bbc.com/news/world-51235105')
df = pd.DataFrame(dfhtml[0])

# %%
df
# Out:
#               Country   Deaths  Death rate*  Total Cases  \
# 0                  US  1012833        308.6     87030788
# 1              Brazil   672033        318.4     32535923
# 2               India   525242         38.4     43531650
# 3              Russia   373595        258.8     18173480
# 4              Mexico   325793        255.4      6093835
# ..                ...      ...          ...          ...
# 220        Micronesia        0          0.0           38
# 221           Vatican        0          0.0           29
# 222  Marshall Islands        0          0.0           18
# 223        Antarctica        0          NaN           11
# 224      Saint Helena        0          0.0            4
#
#      New Cases  0  10  100  1k  10k  **  Unnamed: 5
# 0                                   NaN         NaN
# 1                                   NaN         NaN
# 2                                   NaN         NaN
# 3                                   NaN         NaN
# ...

# %%
dfhtml[0].to_excel("html.xlsx", index = False)

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
temp_db =create_engine("sqlite:///: memory:")

# %%
temp_db.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...

# %%
import sqlite3

# %%
dfhtml[0].to_excel("html.xlsx", index =False)

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
temp_db =create_engine("sqlite:///: memory:") # geçici hafıazadan kullanmak için

# %%
temp_db
# Out:
# Engine(sqlite:///: memory:)

# %%
table = pd.read_html('https://en.wikipedia.org/wiki/World_population')

# %%
temp_db.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...

# %%
import sqlite3

# %%
with sqlite3.connect('sample_data1.db') as cnnt:
    df.to_sql("sample6", cnnt)

# %%
query1 = "SELECT  Country, Population  FROM sample6"

# %%
with sqlite3.connect("sample_data1.db") as ct:
    df6=pd.read_sql(query1,ct)

# %%
f=pd.read_sql(sql="populations",con=temp_db,index_col="index")

pd.read_sql_query(sql="SELECT Country, Population FROM populations",con=temp_db)

df[["Country","Population"]]

df.loc[:,["Country","Population"]]

import sqlite3

# %%
with sqlite3.connect("sample_data1.db") as cnnt:
    df.to_sql("sample", cnnt)

query1 = "SELECT Country, Population FROM sample"

with sqlite3.connect("sample_data1.db") as ct:
    df6=pd.read_sql(query1,ct)
